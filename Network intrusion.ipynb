# %%
#Loading the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Reading the data set
train_data=pd.read_csv("Network_Intrusion_Train_data.csv")
test_data=pd.read_csv("Network_Intrusion_Test_data.csv")

# %% [markdown]
# # Data Analysis

# %%
train_data.head()
# Out:
#    duration protocol_type   service flag  src_bytes  dst_bytes  land  \
# 0         0           tcp  ftp_data   SF        491          0     0
# 1         0           udp     other   SF        146          0     0
# 2         0           tcp   private   S0          0          0     0
# 3         0           tcp      http   SF        232       8153     0
# 4         0           tcp      http   SF        199        420     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# 0               0       0    0  ...                  25
# 1               0       0    0  ...                   1
# 2               0       0    0  ...                  26
# 3               0       0    0  ...                 255
# 4               0       0    0  ...                 255
#
#    dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                    0.17                    0.03
# 1                    0.00                    0.60
# 2                    0.10                    0.05
# ...

# %%
test_data.head()
# Out:
#    duration protocol_type   service  flag  src_bytes  dst_bytes  land  \
# 0         0           tcp   private   REJ          0          0     0
# 1         0           tcp   private   REJ          0          0     0
# 2         2           tcp  ftp_data    SF      12983          0     0
# 3         0          icmp     eco_i    SF         20          0     0
# 4         1           tcp    telnet  RSTO          0         15     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_count  dst_host_srv_count  \
# 0               0       0    0  ...             255                  10
# 1               0       0    0  ...             255                   1
# 2               0       0    0  ...             134                  86
# 3               0       0    0  ...               3                  57
# 4               0       0    0  ...              29                  86
#
#    dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                    0.04                    0.06
# ...

# %%
train_data.info()
#.info() will give us number of rows, number of columns,type of every column , And the the memory storage shared by the dataframe.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25192 entries, 0 to 25191
# Data columns (total 42 columns):
# duration                       25192 non-null int64
# protocol_type                  25192 non-null object
# service                        25192 non-null object
# flag                           25192 non-null object
# src_bytes                      25192 non-null int64
# dst_bytes                      25192 non-null int64
# land                           25192 non-null int64
# wrong_fragment                 25192 non-null int64
# urgent                         25192 non-null int64
# hot                            25192 non-null int64
# num_failed_logins              25192 non-null int64
# logged_in                      25192 non-null int64
# num_compromised                25192 non-null int64
# root_shell                     25192 non-null int64
# su_attempted                   25192 non-null int64
# num_root                       25192 non-null int64
# ...

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22544 entries, 0 to 22543
# Data columns (total 41 columns):
# duration                       22544 non-null int64
# protocol_type                  22544 non-null object
# service                        22544 non-null object
# flag                           22544 non-null object
# src_bytes                      22544 non-null int64
# dst_bytes                      22544 non-null int64
# land                           22544 non-null int64
# wrong_fragment                 22544 non-null int64
# urgent                         22544 non-null int64
# hot                            22544 non-null int64
# num_failed_logins              22544 non-null int64
# logged_in                      22544 non-null int64
# num_compromised                22544 non-null int64
# root_shell                     22544 non-null int64
# su_attempted                   22544 non-null int64
# num_root                       22544 non-null int64
# ...

# %%
train_data.isnull().sum()
#checking for the null values in train data.
# Out:
# duration                       0
# protocol_type                  0
# service                        0
# flag                           0
# src_bytes                      0
# dst_bytes                      0
# land                           0
# wrong_fragment                 0
# urgent                         0
# hot                            0
# num_failed_logins              0
# logged_in                      0
# num_compromised                0
# root_shell                     0
# su_attempted                   0
# num_root                       0
# num_file_creations             0
# num_shells                     0
# num_access_files               0
# num_outbound_cmds              0
# is_host_login                  0
# is_guest_login                 0
# count                          0
# srv_count                      0
# serror_rate                    0
# srv_serror_rate                0
# rerror_rate                    0
# srv_rerror_rate                0
# ...

# %%
test_data.isnull().sum()
#checking for the null values in test data.
# Out:
# duration                       0
# protocol_type                  0
# service                        0
# flag                           0
# src_bytes                      0
# dst_bytes                      0
# land                           0
# wrong_fragment                 0
# urgent                         0
# hot                            0
# num_failed_logins              0
# logged_in                      0
# num_compromised                0
# root_shell                     0
# su_attempted                   0
# num_root                       0
# num_file_creations             0
# num_shells                     0
# num_access_files               0
# num_outbound_cmds              0
# is_host_login                  0
# is_guest_login                 0
# count                          0
# srv_count                      0
# serror_rate                    0
# srv_serror_rate                0
# rerror_rate                    0
# srv_rerror_rate                0
# ...

# %%
#PLoting the heatmap to show visually the null values in our data sets.
sns.heatmap(train_data.isnull())

# %%
sns.heatmap(test_data.isnull())

# %%
# Now will check the relationship between the features of our data set.
train_data.corr()
# Out:
#                              duration  src_bytes  dst_bytes      land  \
# duration                     1.000000   0.084864   0.013258 -0.001012
# src_bytes                    0.084864   1.000000   0.003611 -0.000090
# dst_bytes                    0.013258   0.003611   1.000000 -0.000350
# land                        -0.001012  -0.000090  -0.000350  1.000000
# wrong_fragment              -0.010358  -0.000916  -0.003586 -0.000813
# urgent                      -0.000486  -0.000062   0.000345 -0.000056
# hot                          0.004202   0.000995   0.002539 -0.000819
# num_failed_logins            0.011108  -0.000260   0.005197 -0.000234
# logged_in                   -0.063703  -0.002040   0.012704 -0.007196
# num_compromised              0.095215  -0.000196   0.035852 -0.000195
# root_shell                   0.050547  -0.000383   0.020214 -0.000351
# su_attempted                 0.094243  -0.000267   0.035041 -0.000247
# ...

# %%
#will show the correlation of features of our data set.
sns.heatmap(train_data.corr())

# %%
# By observation we know that there are some catagorical features are present in the data set.
#We will convert those feature to numeric by one-hot-encoding.Pandas provide a vary beautiful function called .get_dummies() which will do all our work.
#First we will select which columns are catagorical by making the list of those column names.
cat_col=['protocol_type', 'service', 'flag']
#now we will get the dummy values of these columns and assign those to the new variable called dum_train/dum_test.
dum_train=pd.get_dummies(train_data[cat_col],drop_first=True)
dum_test=pd.get_dummies(test_data[cat_col],drop_first=True)
dum_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25192 entries, 0 to 25191
# Data columns (total 77 columns):
# protocol_type_tcp      25192 non-null uint8
# protocol_type_udp      25192 non-null uint8
# service_X11            25192 non-null uint8
# service_Z39_50         25192 non-null uint8
# service_auth           25192 non-null uint8
# service_bgp            25192 non-null uint8
# service_courier        25192 non-null uint8
# service_csnet_ns       25192 non-null uint8
# service_ctf            25192 non-null uint8
# service_daytime        25192 non-null uint8
# service_discard        25192 non-null uint8
# service_domain         25192 non-null uint8
# service_domain_u       25192 non-null uint8
# service_echo           25192 non-null uint8
# service_eco_i          25192 non-null uint8
# service_ecr_i          25192 non-null uint8
# service_efs            25192 non-null uint8
# service_exec           25192 non-null uint8
# service_finger         25192 non-null uint8
# ...

# %%
# Now we will drop the previous catagorical variable from the dataset
train_data.drop(cat_col,axis=1,inplace=True)
test_data.drop(cat_col,axis=1,inplace=True)

# %%
#In our train data we have one extra variable i.e target variable
#we will convert that using Encoder
from sklearn.preprocessing import LabelEncoder 
le= LabelEncoder()
train_data["class"]=le.fit_transform(train_data["class"])
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25192 entries, 0 to 25191
# Data columns (total 39 columns):
# duration                       25192 non-null int64
# src_bytes                      25192 non-null int64
# dst_bytes                      25192 non-null int64
# land                           25192 non-null int64
# wrong_fragment                 25192 non-null int64
# urgent                         25192 non-null int64
# hot                            25192 non-null int64
# num_failed_logins              25192 non-null int64
# logged_in                      25192 non-null int64
# num_compromised                25192 non-null int64
# root_shell                     25192 non-null int64
# su_attempted                   25192 non-null int64
# num_root                       25192 non-null int64
# num_file_creations             25192 non-null int64
# num_shells                     25192 non-null int64
# num_access_files               25192 non-null int64
# ...

# %%
#Now we will concatinate the our data and converted data
final_train=pd.concat((train_data,dum_train),axis=1)
final_test=pd.concat((test_data,dum_test),axis=1)

# %% [markdown]
# # Feature Selection by Ensamble Method:

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectFromModel

# %%
F_rf=RandomForestClassifier()

# %%
F_rf.fit(final_train.drop("class",axis=1),final_train["class"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=10,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
#Ploting the importance of the data.
feature_importance=F_rf.feature_importances_
#make importance relative to max importance
feature_importance=100.0*(feature_importance/ feature_importance.max()) # Standardizing the data
sorted_idx = np.argsort(feature_importance)
pos=np.arange(sorted_idx.shape[0])+.5
plt.figure(figsize=(30,30))
plt.subplot(1,2,2)
plt.barh(pos,feature_importance[sorted_idx],align="center")
plt.yticks(pos,final_train.drop("class",axis=1).columns[sorted_idx])
plt.xlabel("Relative importance")
plt.title("variable importance")
plt.show()

# %%
#selecting the important features using the SelectFromModel() 
sklearn.feature_selection import SelectFromModel
sel=SelectFromModel(RandomForestClassifier(n_estimators=25))

# %%
sel.fit(final_train.drop("class",axis=True),final_train["class"])
# Out:
# SelectFromModel(estimator=RandomForestClassifier(bootstrap=True,
#                                                  class_weight=None,
#                                                  criterion='gini',
#                                                  max_depth=None,
#                                                  max_features='auto',
#                                                  max_leaf_nodes=None,
#                                                  min_impurity_decrease=0.0,
#                                                  min_impurity_split=None,
#                                                  min_samples_leaf=1,
#                                                  min_samples_split=2,
#                                                  min_weight_fraction_leaf=0.0,
#                                                  n_estimators=25, n_jobs=None,
#                                                  oob_score=False,
# ...

# %%
len(sel.get_support())
# Out:
# 115

# %%
#splitting oyr the data into train and test
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(final_train.drop("class",axis=1).iloc[:,sel.get_support()],final_train['class'],test_size=.3,random_state=101)

# %%
from sklearn.linear_model import LogisticRegression

# %%
#Fitting the model
log_model=LogisticRegression()

# %%
log_model.fit(x_train,y_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
#prediction
predict_train=log_model.predict(x_train)
predict_test=log_model.predict(x_test)

# %%
from sklearn.metrics import roc_curve,classification_report,accuracy_score,auc,confusion_matrix

# %%
print("Accuracy:",accuracy_score(y_train,predict_train),"\n","Classification report:\n",classification_report(y_train,predict_train))
print("Accuracy:",accuracy_score(y_test,predict_test),"\n","Classification report:\n",classification_report(y_test,predict_test))
# Out:
# Accuracy: 0.8904956334354088
#  Classification report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.83      0.88      8242
#            1       0.87      0.94      0.90      9392
#
#     accuracy                           0.89     17634
#    macro avg       0.90      0.89      0.89     17634
# weighted avg       0.89      0.89      0.89     17634
#
# Accuracy: 0.899311987298227
#  Classification report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.84      0.89      3501
#            1       0.88      0.95      0.91      4057
#
#     accuracy                           0.90      7558
#    macro avg       0.90      0.90      0.90      7558
# weighted avg       0.90      0.90      0.90      7558

# %%
cm=confusion_matrix(y_test,predict_test)
#cploting confussion matrix
sns.heatmap(pd.DataFrame(cm),annot=True)

# %%
#Determine the false position and true possitive rates
FPR, TPR, _=roc_curve(y_train,predict_train)
FPR1,TPR1,_1=roc_curve(y_test,predict_test)

# %%
# Calculate the AUC
roc_auc=auc(FPR,TPR)
print("ROC AUC:%0.3f" % roc_auc)


roc_auc1=auc(FPR1,TPR1)
print("ROC AUC:%0.3f" % roc_auc1)
# Out:
# ROC AUC:0.887
# ROC AUC:0.895

# %%
#plot of a ROC curve
plt.figure(figsize=(10,10))
plt.plot(FPR,TPR,label="ROC curve (area=%0.3f)" % roc_auc)
plt.plot(FPR1,TPR1,label="ROC curve (area=%0.3f)" % roc_auc1)
plt.plot([0,1],[0,1],'k--')
plt.xlim([-0.05,1.0])
plt.xlim([0.0 , 1.05])
plt.xlabel("false possitive rate")
plt.ylabel("true possitive rate")
plt.title("ROC CURVE")
plt.legend(loc="lower right")
plt.show()

# %%
RF_model=RandomForestClassifier()

# %%
RF_model.fit(x_train,y_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=10,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
#prediction
predict_train=log_model.predict(x_train)
predict_test=log_model.predict(x_test)

# %%
print("Accuracy:",accuracy_score(y_train,predict_train),"\n","Classification report:\n",classification_report(y_train,predict_train))
print("Accuracy:",accuracy_score(y_test,predict_test),"\n","Classification report:\n",classification_report(y_test,predict_test))
# Out:
# Accuracy: 0.8904956334354088
#  Classification report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.83      0.88      8242
#            1       0.87      0.94      0.90      9392
#
#     accuracy                           0.89     17634
#    macro avg       0.90      0.89      0.89     17634
# weighted avg       0.89      0.89      0.89     17634
#
# Accuracy: 0.899311987298227
#  Classification report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.84      0.89      3501
#            1       0.88      0.95      0.91      4057
#
#     accuracy                           0.90      7558
#    macro avg       0.90      0.90      0.90      7558
# weighted avg       0.90      0.90      0.90      7558

# %%
cm=confusion_matrix(y_test,predict_test)
#cploting confussion matrix
sns.heatmap(pd.DataFrame(cm),annot=True)

# %%
#Determine the false position and true possitive rates
FPR, TPR, _=roc_curve(y_train,predict_train)
FPR1,TPR1,_1=roc_curve(y_test,predict_test)

# %%
# Calculate the AUC
roc_auc=auc(FPR,TPR)
print("ROC AUC:%0.3f" % roc_auc)


roc_auc1=auc(FPR1,TPR1)
print("ROC AUC:%0.3f" % roc_auc1)
# Out:
# ROC AUC:0.887
# ROC AUC:0.895

# %%
#plot of a ROC curve
plt.figure(figsize=(10,10))
plt.plot(FPR,TPR,label="ROC curve (area=%0.3f)" % roc_auc)
plt.plot(FPR1,TPR1,label="ROC curve (area=%0.3f)" % roc_auc1)
plt.plot([0,1],[0,1],'k--')
plt.xlim([-0.05,1.0])
plt.xlim([0.0 , 1.05])
plt.xlabel("false possitive rate")
plt.ylabel("true possitive rate")
plt.title("ROC CURVE")
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# - Here Randomforest working little bit better than logistic. Then we will go with the Randomforest

# %%
future_data=final_test.loc[:,x_train.columns]

# %%
#prediction for the test data
future_data["class"]=RF_model.predict(future_data)

# %%
future_data.head()
# Out:
#    src_bytes  dst_bytes  logged_in  num_compromised  count  srv_count  \
# 0          0          0          0                0    229         10
# 1          0          0          0                0    136          1
# 2      12983          0          0                0      1          1
# 3         20          0          0                0      1         65
# 4          0         15          0                0      1          8
#
#    serror_rate  srv_serror_rate  same_srv_rate  diff_srv_rate  ...  \
# 0          0.0             0.00           0.04           0.06  ...
# 1          0.0             0.00           0.01           0.06  ...
# 2          0.0             0.00           1.00           0.00  ...
# 3          0.0             0.00           1.00           0.00  ...
# 4          0.0             0.12           1.00           0.00  ...
#
#    dst_host_srv_diff_host_rate  dst_host_serror_rate  \
# 0                         0.00                   0.0
# ...
